# %% [markdown]
# # Gravity sparse inversion: single `Inversion` object

# %%
import discretize
import harmonica as hm
import matplotlib.pyplot as plt
import numpy as np
import verde as vd
from simpeg.maps import IdentityMap
from simpeg.potential_fields.gravity import (
    Point,
    Simulation3DIntegral,
    SourceField,
    Survey,
)
from simpeg.utils import depth_weighting, model_builder

import inversion_ideas as ii

# %% [markdown]
# ## Define synthetic data with two prisms

# %%
prisms = [
    (-60, -40, -10, 10, -70, -50),
    (40, 60, -10, 10, -70, -50),
]
densities = np.array([-200, 200])  # SI units

region = (-100, 100, -100, 100)
shape = (31, 31)
height = 0
coordinates = vd.grid_coordinates(region, shape=shape, extra_coords=height)

# %%
gz = hm.prism_gravity(coordinates, prisms, densities, field="g_z")
gz *= -1  # Invert sign to work with upward component

# Add noise
stderr = vd.maxabs(gz) * 0.01
gz += np.random.default_rng(seed=51).normal(scale=stderr, size=gz.shape)

print(f"{stderr=}")
# Out:
# stderr=np.float64(2.5745854651805945e-05)

# %%
tmp = plt.pcolormesh(*coordinates[:2], gz)
plt.gca().set_aspect("equal")
plt.colorbar(tmp)
plt.show()

# %%
gz.size
# Out:
# 961

# %% [markdown]
# ## Define SimPEG simulation

# %%
# h = [(5.0, 40)]
h = [(10.0, 20)]
mesh = discretize.TensorMesh(h=[h, h, h], origin="CCN")
mesh
# Out:
#   TensorMesh: 8,000 cells
#
#                       MESH EXTENT             CELL WIDTH      FACTOR
#   dir    nC        min           max         min       max      max
#   ---   ---  ---------------------------  ------------------  ------
#    x     20       -100.00        100.00     10.00     10.00    1.00
#    y     20       -100.00        100.00     10.00     10.00    1.00
#    z     20       -200.00          0.00     10.00     10.00    1.00

# %%
locations = np.vstack(tuple(c.ravel() for c in coordinates)).T
receivers = Point(locations, components="gz")
source = SourceField(receiver_list=[receivers])
survey = Survey(source)

# %%
simulation_simpeg = Simulation3DIntegral(mesh, survey=survey, rhoMap=IdentityMap(mesh))

# %%
def block_corners(prism):
    p0 = np.array([prism[0], prism[2], prism[4]])
    p1 = np.array([prism[1], prism[3], prism[5]])
    return p0, p1

# %%
model = np.zeros(mesh.n_cells)
densities_gcc = densities * 1e-3
print(densities_gcc)

for prism, density in zip(prisms, densities_gcc, strict=True):
    p0, p1 = block_corners(prism)
    model = model_builder.add_block(mesh.cell_centers, model, p0, p1, density)
# Out:
# [-0.2  0.2]

# %%
mesh.plot_slice(model, normal="Y", slice_loc=0)
# Out:
# (<matplotlib.collections.QuadMesh at 0x7f3277586210>,)

# %%
dpred = simulation_simpeg.dpred(model)

# %%
tmp = plt.pcolormesh(*coordinates[:2], dpred.reshape(coordinates[0].shape))
plt.gca().set_aspect("equal")
plt.colorbar(tmp)
plt.show()

# %% [markdown]
# ## Sparse gravity inversion

# %% [markdown]
# Wrap SimPEG's simulation into a child of the new `Simulation` class:

# %%
simulation = ii.wrap_simulation(simulation_simpeg, store_jacobian=True)

# %%
uncertainties = stderr * np.ones(gz.size)
data_misfit = ii.DataMisfit(gz.ravel(), uncertainties, simulation)

# %%
active_cells = np.ones(mesh.n_cells, dtype=bool)
depth_weights = depth_weighting(mesh, 0)
sparse_smallness = ii.SparseSmallness(
    mesh=mesh,
    active_cells=active_cells,
    norm=1,
    model_previous=None,
    cell_weights=depth_weights,
    irls=False,  # Start with IRLS deactivated
)

# %%
beta_0 = 1e4
regularization = beta_0 * sparse_smallness
phi = data_misfit + regularization
phi
# Out:
# φd(m) + 1.00e+04 φs-1(m)

# %%
# Initial model
initial_model = np.zeros(simulation.n_params)

# Stopping criteria
smallness_not_changing = ii.ObjectiveChanged(sparse_smallness, rtol=1e-3)

# Define irls directive
irls_directive = ii.IrlsFull(
    sparse_smallness,
    data_misfit=data_misfit,
    regularization=regularization,
)

# Preconditioner that updates on each iteration
preconditioner = ii.JacobiPreconditioner(phi)
minimizer_kwargs = dict(preconditioner=preconditioner)

# Define sparse inversion
sparse_inversion = ii.Inversion(
    phi,
    initial_model,
    ii.conjugate_gradient,
    directives=[irls_directive],
    stopping_criteria=smallness_not_changing,
    cache_models=True,
    max_iterations=80,
    minimizer_kwargs=minimizer_kwargs,
)

# Add columns to log
sparse_inversion.log.add_column("irls active?", lambda _, __: sparse_smallness.irls)
sparse_inversion.log.add_column(
    "irls threshold", lambda _, __: sparse_smallness.threshold
)
sparse_inversion.log.add_column(
    "|phi_m - phi_m*| / |phi_m*|", lambda _, model: smallness_not_changing.ratio(model)
)

# %%
model = sparse_inversion.run()
# Out:
# Output()
# INFO: 🎉 Inversion successfully finished due to stopping criteria.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
sparse_inversion.stopping_criteria.info(model)
# Out:
# [x] ObjectiveChanged
# ├── Condition: |φ(m) - φ(m_prev)| <= max(|φ(m_prev)| * rtol, atol)
# ├── |φ(m) - φ(m_prev)| = 4.81e-01
# ├── |φ(m_prev)|        = 5.03e+02
# ├── rtol               = 1.00e-03
# └── atol               = 0.00e+00

# %%
log = sparse_inversion.log.to_pandas()
log
# Out:
#               beta         phi_d       phi_m   beta * phi_m           phi  \
# iter
# 0     10000.000000  1.667546e+06    0.000000       0.000000  1.667546e+06
# 1     10000.000000  7.071325e+02    0.732816    7328.160613  8.035293e+03
# 2     10000.000000  5.606017e+05   39.991161  399911.611792  9.605133e+05
# 3      3756.306907  2.055811e+05   97.445323  366034.539091  5.716157e+05
# 4      1415.075330  5.266998e+04  160.431131  227022.135434  2.796921e+05
# 5       540.152454  1.112071e+04  204.362889  110387.116120  1.215078e+05
# 6       219.730508  2.761752e+03  226.708439   49814.760371  5.257651e+04
# 7       110.529376  1.273082e+03  235.789267   26061.640578  2.733472e+04
# 8        72.145250  9.459025e+02  239.383634   17270.392005  1.821629e+04
# 9        54.021442  8.285917e+02  241.247012   13032.511557  1.386110e+04
# 10       43.309395  7.704035e+02  242.444459   10500.122821  1.127053e+04
# 11       43.309395  8.107333e+02  282.413607   12231.162423  1.304190e+04
# 12       35.128542  7.612122e+02  283.678165    9965.200437  1.072641e+04
# 13       35.128542  7.937577e+02  324.225395   11389.565548  1.218332e+04
# 14       28.820634  7.519456e+02  325.534992    9382.124835  1.013407e+04
# 15       28.820634  7.779369e+02  364.085689   10493.180350  1.127112e+04
# 16       23.906491  7.428305e+02  365.419345    8735.894443  9.478725e+03
# 17       23.906491  7.632317e+02  399.716491    9555.818889  1.031905e+04
# 18       23.906491  7.842621e+02  428.471657   10243.254020  1.102752e+04
# 19       19.742619  7.485061e+02  430.112970    8491.556321  9.240062e+03
# 20       19.742619  7.634719e+02  452.420566    8931.966675  9.695439e+03
# 21       19.742619  7.790612e+02  469.315388    9265.514706  1.004458e+04
# 22       16.363399  7.462775e+02  471.135078    7709.371474  8.455649e+03
# 23       16.363399  7.571763e+02  482.845728    7900.997529  8.658174e+03
# 24       16.363399  7.696839e+02  491.193090    8037.588742  8.807273e+03
# 25       16.363399  7.832352e+02  496.676513    8127.316190  8.910551e+03
# 26       13.523003  7.509994e+02  498.839106    6745.802894  7.496802e+03
# 27       13.523003  7.608503e+02  501.621324    6783.426835  7.544277e+03
# 28       13.523003  7.729367e+02  503.308344    6806.240415  7.579177e+03
# 29       13.523003  7.859194e+02  503.789256    6812.743786  7.598663e+03
#
#               chi  irls active?  irls threshold  |phi_m - phi_m*| / |phi_m*|
# iter
# 0     1735.219131         False    1.000000e-08                          NaN
# 1        0.735830         False    1.000000e-08                          inf
# 2      583.352398          True    2.595772e-03                    53.571895
# 3      213.924162          True    2.595772e-03                     1.436672
# 4       54.807469          True    2.595772e-03                     0.646371
# 5       11.572018          True    2.595772e-03                     0.273836
# 6        2.873832          True    2.595772e-03                     0.109343
# 7        1.324747          True    2.595772e-03                     0.040055
# 8        0.984290          True    2.595772e-03                     0.015244
# 9        0.862218          True    2.595772e-03                     0.007784
# 10       0.801669          True    2.595772e-03                     0.004964
# 11       0.843635          True    2.076618e-03                     0.164859
# 12       0.792104          True    2.076618e-03                     0.004478
# 13       0.825971          True    1.661294e-03                     0.142934
# 14       0.782462          True    1.661294e-03                     0.004039
# 15       0.809508          True    1.329035e-03                     0.118423
# 16       0.772977          True    1.329035e-03                     0.003663
# 17       0.794206          True    1.063228e-03                     0.093857
# 18       0.816090          True    8.505827e-04                     0.071939
# 19       0.778883          True    8.505827e-04                     0.003831
# 20       0.794456          True    6.804661e-04                     0.051865
# 21       0.810678          True    5.443729e-04                     0.037343
# 22       0.776564          True    5.443729e-04                     0.003877
# 23       0.787905          True    4.354983e-04                     0.024856
# 24       0.800920          True    3.483987e-04                     0.017288
# 25       0.815021          True    2.787189e-04                     0.011163
# 26       0.781477          True    2.787189e-04                     0.004354
# 27       0.791728          True    2.229751e-04                     0.005577
# 28       0.804305          True    1.783801e-04                     0.003363
# 29       0.817814          True    1.427041e-04                     0.000956

# %%
fig, axes = plt.subplots(nrows=4, ncols=1, sharex=True, figsize=(6, 12))
axes[0].plot(log.index, log.beta, ".-")
axes[0].set_yscale("log")
axes[0].set_ylabel("Beta")

axes[1].plot(log.index, log.phi_d, ".-")
axes[1].axhline(data_misfit.n_data, linestyle="--", color="grey")
axes[1].set_ylabel("Data misfit")
axes[1].set_yscale("log")

axes[2].plot(log.index, log.phi_m, ".-")
axes[2].set_ylabel("Model norm")

axes[3].plot(log.index, log["|phi_m - phi_m*| / |phi_m*|"], ".-")
axes[3].set_ylabel(r"$|\phi_m - \phi_m^{*}| / |\phi_m^{*}|$")
axes[3].set_yscale("log")

plt.show()

# %%
for i, model in enumerate(sparse_inversion.models):
    (tmp,) = mesh.plot_slice(model, normal="Y", slice_loc=0)
    plt.colorbar(tmp, label="g/cc")
    plt.title(f"Model {i}")
    plt.show()
